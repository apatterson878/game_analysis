# %% [markdown]
# # Heroes Of Pymoli Data Analysis

# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * While most of the players are male, females spend more (9.8%) per person on items.
# * Players in the age range of 35-39 spent more per person then the other age groups.
# * "Oathbreaker, Last Hope of the Breaking Storm" was the most popular and profitable item sold.

# %%
import pandas as pd
import numpy as np

file_to_load = "Resources/purchase_data.csv"

purchase_data = pd.read_csv(file_to_load)
nodupe_purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Get count of unique screen names

# %%
total_players =purchase_data["SN"].nunique()
#insert count into a new DF
player_df = pd.DataFrame(
    {"Total Players": [total_players]
     }
)
player_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %%
unique_items =purchase_data["Item ID"].nunique()
avg_price = purchase_data["Price"].mean()
avg_price = round(avg_price,2)
total_rev = purchase_data["Price"].sum()
count_purchase =purchase_data["Price"].count()

# %%
purchase_analysis = pd.DataFrame(
    {"Number of Unique Items": [unique_items],
     "Average Price": [avg_price],
     "Number of Purchases": [count_purchase],
     "Total Revenue": [total_rev],
     }
)
purchase_analysis['Total Revenue']= purchase_analysis['Total Revenue'].map('${:,.2f}'.format)
purchase_analysis['Average Price']= purchase_analysis['Average Price'].map('${:,.2f}'.format)
purchase_analysis
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %%
nodupe_purchase_data.drop_duplicates(subset ='SN',inplace=True)

# %%
genders = nodupe_purchase_data["Gender"]
total_count = nodupe_purchase_data["Gender"].value_counts()
df = pd.DataFrame(total_count)

# %%
percent = round(df['Gender']/df['Gender'].sum()*100,2)
# percent = pd.DataFrame(percent)
gender_demo = pd.concat([df,percent], axis = 1)
gender_demo.columns = ['Gender', 'Percentage of Players']

gender_demo['Percentage of Players']= gender_demo['Percentage of Players'].map('{:,.2f}%'.format)

gender_demo
# Out:
#                        Gender Percentage of Players
# Male                      484                84.03%
# Female                     81                14.06%
# Other / Non-Disclosed      11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %%
purch_analysis = purchase_data.groupby(["Gender"])
purch_count = purch_analysis["SN"].count()
purch_avg = purch_analysis["Price"].mean()
purch_total = purch_analysis["Price"].sum()
person = purch_analysis["SN"].nunique()
avg_purch_total = (purch_total / person )

# %%
the_data_frame = pd.DataFrame({"Purchase Count": purch_count,
                                    "Average Purchase Price": purch_avg,
                                    "Total Purchase Value":purch_total,
                                    "Avg Total Purchase per Person":avg_purch_total
                                   })
the_data_frame['Average Purchase Price']= the_data_frame['Average Purchase Price'].map('${:,.2f}'.format)
the_data_frame['Total Purchase Value']= the_data_frame['Total Purchase Value'].map('${:,.2f}'.format)
the_data_frame['Avg Total Purchase per Person']= the_data_frame['Avg Total Purchase per Person'].map('${:,.2f}'.format)

the_data_frame.head()
# Out:
#                        Purchase Count Average Purchase Price  \
# Gender
# Female                            113                  $3.20
# Male                              652                  $3.02
# Other / Non-Disclosed              15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %%
age_group = nodupe_purchase_data.groupby("Age")
bins = [0, 9, 14, 19, 24, 29, 34, 39, 99]
group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34",
                "35-39", "40+"]

# %%
nodupe_purchase_data["Age Data"] = pd.cut(nodupe_purchase_data["Age"], bins, labels=group_labels)

# %%
age_group = nodupe_purchase_data.groupby("Age Data")

# %%
total_counts = age_group["Gender"].count()
person = age_group["SN"].nunique()
purch_total = age_group["Age"].sum()
total_countsum = age_group["Gender"].count().sum()
percent_players = (person / total_countsum )*100

not_another_df = pd.DataFrame({"Total Count": total_counts,
                               "Percentage of Players": percent_players 
                                   })
not_another_df['Percentage of Players']= not_another_df['Percentage of Players'].map('{:,.2f}%'.format)


not_another_df
# Out:
#           Total Count Percentage of Players
# Age Data
# <10                17                 2.95%
# 10-14              22                 3.82%
# 15-19             107                18.58%
# 20-24             258                44.79%
# 25-29              77                13.37%
# 30-34              52                 9.03%
# 35-39              31                 5.38%
# 40+                12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %%
purchase_data["Age Data"] = pd.cut(purchase_data["Age"], bins, labels=group_labels)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Data
# 0  Extraction, Quickblade Of Trembling Hands   3.53    20-24
# 1                          Frenzied Scimitar   1.56      40+
# 2                               Final Critic   4.88    20-24
# 3                                Blindscythe   3.27    20-24
# 4                                       Fury   1.44    20-24

# %%
purch_analysis_age = purchase_data.groupby("Age Data")
bins = [0, 9, 14, 19, 24, 29, 34, 39, 99]
group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34",
                "35-39", "40+"]

# %%
purch_count = purch_analysis_age["SN"].count()
purch_avg = purch_analysis_age["Price"].mean()
purch_total = purch_analysis_age["Price"].sum()
persons = purch_analysis_age["SN"].nunique()
avg_purch_total = (purch_total / persons )

# %%
purch_analysis_age_df = pd.DataFrame({"Purchase Count": purch_count,
                                    "Average Purchase Price": purch_avg,
                                    "Total Purchase Value":purch_total,
                                    "Avg Total Purchase per Person":avg_purch_total
                                   })
purch_analysis_age_df['Average Purchase Price']= purch_analysis_age_df['Average Purchase Price'].map('${:,.2f}'.format)
purch_analysis_age_df['Total Purchase Value']= purch_analysis_age_df['Total Purchase Value'].map('${:,.2f}'.format)
purch_analysis_age_df['Avg Total Purchase per Person']= purch_analysis_age_df['Avg Total Purchase per Person'].map('${:,.2f}'.format)

purch_analysis_age_df
# Out:
#           Purchase Count Average Purchase Price Total Purchase Value  \
# Age Data
# <10                   23                  $3.35               $77.13
# 10-14                 28                  $2.96               $82.78
# 15-19                136                  $3.04              $412.89
# 20-24                365                  $3.05            $1,114.06
# 25-29                101                  $2.90              $293.00
# 30-34                 73                  $2.93              $214.00
# 35-39                 41                  $3.60              $147.67
# 40+                   13                  $2.94               $38.24
#
#          Avg Total Purchase per Person
# Age Data
# <10                              $4.54
# 10-14                            $3.76
# 15-19                            $3.86
# 20-24                            $4.32
# 25-29                            $3.81
# 30-34                            $4.12
# 35-39                            $4.76
# 40+                              $3.19

# %% [markdown]
# ## Top Spenders

# %%
purchase_data.reset_index()
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Data
# 0  Extraction, Quickblade Of Trembling Hands   3.53    20-24
# 1                          Frenzied Scimitar   1.56      40+
# 2                               Final Critic   4.88    20-24
# 3                                Blindscythe   3.27    20-24
# 4                                       Fury   1.44    20-24

# %%
big_money = purchase_data.groupby("SN")


purchase_count_spender = big_money["SN"].count()
purch_price_avg_spender = big_money["Price"].mean()
purch_total_spender = big_money["Price"].sum()


big_money_spenders = pd.DataFrame({"Purchase Count": purchase_count_spender,
                                   "Average Purchase Price": purch_price_avg_spender.astype("float"),
                                   "Total Purchase Value":purch_total_spender.astype("float"),
                                   })
big_money_spenders= big_money_spenders.sort_values("Total Purchase Value", ascending=False)

big_money_spenders["Average Purchase Price"]= big_money_spenders["Average Purchase Price"].map('${:,.2f}'.format)
big_money_spenders["Total Purchase Value"]= big_money_spenders["Total Purchase Value"].map('${:,.2f}'.format)
big_money_spenders.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %%
popular = purchase_data.groupby(['Item ID','Item Name'])

# %%
popular_purchase_count = popular["SN"].count()
popular_purchase_value = popular["Price"].sum()
popular_items_price = popular["Price"].max()

# %%
most_popular = pd.DataFrame({"Purchase Count": popular_purchase_count,
                                   "Item Price": popular_items_price.astype("float"),
                                    "Total Purchase Value":popular_purchase_value.astype("float"),
                                   })
most_popular.head()
most_profit = most_popular.copy()

# %%
most_popular['Item Price']= most_popular['Item Price'].map('${:,.2f}'.format)
most_popular['Total Purchase Value']= most_popular['Total Purchase Value'].map('${:,.2f}'.format)

# %%
most_popular = most_popular.sort_values("Purchase Count", ascending=False)
most_popular.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 82      Nirvana                                                    $44.10
# 19      Pursuit, Cudgel of Necromancy                               $8.16

# %% [markdown]
# ## Most Profitable Items

# %%
most_profit = most_profit.sort_values("Total Purchase Value", ascending=False)
most_profit['Item Price']= most_profit['Item Price'].map('${:,.2f}'.format)
most_profit['Total Purchase Value']= most_profit['Total Purchase Value'].map('${:,.2f}'.format)
most_profit.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 92      Final Critic                                               $39.04
# 103     Singed Scalpel                                             $34.80

# %%
most_profit
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
# 59      Lightning, Etcher of the King                              8
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 78      Glimmer, Ender of the Moon                                 7
# 72      Winter's Bite                                              8
# 60      Wolf                                                       8
# 179     Wolf, Promise of the Moonwalker                            6
# 160     Azurewrath                                                 6
# 25      Hero Cane                                                  6
# 37      Shadow Strike, Glory of Ending Hope                        8
# 139     Mercy, Katana of Dismay                                    5
# 128     Blazeguard, Reach of Eternity                              5
# 138     Peacekeeper, Wit of Dark Magic                             5
# 141     Persuasion                                                 7
# 87      Deluge, Edge of the West                                   5
# 159     Oathbreaker, Spellblade of Trials                          7
# 136     Ghastly Adamantite Protector                               6
# 65      Conqueror Adamantite Mace                                  5
# 101     Final Critic                                               5
# 102     Avenger                                                    6
# 133     Faith's Scimitar                                           5
# 39      Betrayal, Whisper of Grieving Widows                       5
# 111     Misery's End                                               4
# 165     Bone Crushing Silver Skewer                                4
# 75      Brutality Ivory Warmace                                    8
# 52      Hatred                                                     4
# ...                                                              ...
# 124     Venom Claymore                                             4
# 0       Splinter                                                   4
# 155     War-Forged Gold Deflector                                  5
# 48      Rage, Legacy of the Lone Victor                            2
# 158     Darkheart, Butcher of the Champion                         2
# 51      Endbringer                                                 1
# 134     Undead Crusader                                            1
# 30      Stormcaller                                                2
# 135     Warped Diamond Crusader                                    3
# 91      Celeste                                                    1
# 177     Winterthorn, Defender of Shifting Worlds                   2
# 70      Hope's End                                                 4
# 115     Spectral Diamond Doomblade                                 2
# 69      Frenzy, Defender of the Harvest                            2
# 47      Alpha, Reach of Ending Hope                                1
# 180     Stormcaller                                                1
# 27      Riddle, Tribute of Ended Dreams                            1
# 183     Dragon's Greatsword                                        3
# 31      Trickster                                                  2
# 168     Sun Strike, Jaws of Twisted Visions                        2
# 90      Betrayer                                                   1
# 33      Curved Axe                                                 2
# 26      Unholy Wand                                                2
# 118     Ghost Reaver, Longsword of Magic                           1
# 28      Flux, Destroyer of Due Diligence                           2
# 125     Whistling Mithril Warblade                                 2
# 126     Exiled Mithril Longsword                                   1
# 23      Crucifer                                                   1
# 104     Gladiator's Glaive                                         1
# 42      The Decapitator                                            1
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
# 59      Lightning, Etcher of the King                     $4.23
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 78      Glimmer, Ender of the Moon                        $4.40
# 72      Winter's Bite                                     $3.77
# 60      Wolf                                              $3.54
# 179     Wolf, Promise of the Moonwalker                   $4.48
# 160     Azurewrath                                        $4.40
# 25      Hero Cane                                         $4.35
# 37      Shadow Strike, Glory of Ending Hope               $3.16
# 139     Mercy, Katana of Dismay                           $4.94
# 128     Blazeguard, Reach of Eternity                     $4.91
# 138     Peacekeeper, Wit of Dark Magic                    $4.74
# 141     Persuasion                                        $3.19
# 87      Deluge, Edge of the West                          $4.43
# 159     Oathbreaker, Spellblade of Trials                 $3.08
# 136     Ghastly Adamantite Protector                      $3.58
# 65      Conqueror Adamantite Mace                         $4.24
# 101     Final Critic                                      $4.19
# 102     Avenger                                           $3.44
# 133     Faith's Scimitar                                  $4.09
# 39      Betrayal, Whisper of Grieving Widows              $3.94
# 111     Misery's End                                      $4.89
# 165     Bone Crushing Silver Skewer                       $4.86
# 75      Brutality Ivory Warmace                           $2.42
# 52      Hatred                                            $4.84
# ...                                                         ...
# 124     Venom Claymore                                    $1.29
# 0       Splinter                                          $1.28
# 155     War-Forged Gold Deflector                         $1.01
# 48      Rage, Legacy of the Lone Victor                   $2.48
# 158     Darkheart, Butcher of the Champion                $2.45
# 51      Endbringer                                        $4.66
# 134     Undead Crusader                                   $4.50
# 30      Stormcaller                                       $2.21
# 135     Warped Diamond Crusader                           $1.40
# 91      Celeste                                           $4.17
# 177     Winterthorn, Defender of Shifting Worlds          $2.08
# 70      Hope's End                                        $1.03
# 115     Spectral Diamond Doomblade                        $2.04
# 69      Frenzy, Defender of the Harvest                   $1.98
# 47      Alpha, Reach of Ending Hope                       $3.58
# 180     Stormcaller                                       $3.36
# 27      Riddle, Tribute of Ended Dreams                   $3.30
# 183     Dragon's Greatsword                               $1.09
# 31      Trickster                                         $1.55
# 168     Sun Strike, Jaws of Twisted Visions               $1.48
# 90      Betrayer                                          $2.94
# 33      Curved Axe                                        $1.16
# 26      Unholy Wand                                       $1.12
# 118     Ghost Reaver, Longsword of Magic                  $2.17
# 28      Flux, Destroyer of Due Diligence                  $1.06
# 125     Whistling Mithril Warblade                        $1.00
# 126     Exiled Mithril Longsword                          $2.00
# 23      Crucifer                                          $1.99
# 104     Gladiator's Glaive                                $1.93
# 42      The Decapitator                                   $1.75
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 92      Final Critic                                               $39.04
# 103     Singed Scalpel                                             $34.80
# 59      Lightning, Etcher of the King                              $33.84
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 78      Glimmer, Ender of the Moon                                 $30.80
# 72      Winter's Bite                                              $30.16
# 60      Wolf                                                       $28.32
# 179     Wolf, Promise of the Moonwalker                            $26.88
# 160     Azurewrath                                                 $26.40
# 25      Hero Cane                                                  $26.10
# 37      Shadow Strike, Glory of Ending Hope                        $25.28
# 139     Mercy, Katana of Dismay                                    $24.70
# 128     Blazeguard, Reach of Eternity                              $24.55
# 138     Peacekeeper, Wit of Dark Magic                             $23.70
# 141     Persuasion                                                 $22.33
# 87      Deluge, Edge of the West                                   $22.15
# 159     Oathbreaker, Spellblade of Trials                          $21.56
# 136     Ghastly Adamantite Protector                               $21.48
# 65      Conqueror Adamantite Mace                                  $21.20
# 101     Final Critic                                               $20.95
# 102     Avenger                                                    $20.64
# 133     Faith's Scimitar                                           $20.45
# 39      Betrayal, Whisper of Grieving Widows                       $19.70
# 111     Misery's End                                               $19.56
# 165     Bone Crushing Silver Skewer                                $19.44
# 75      Brutality Ivory Warmace                                    $19.36
# 52      Hatred                                                     $19.36
# ...                                                                   ...
# 124     Venom Claymore                                              $5.16
# 0       Splinter                                                    $5.12
# 155     War-Forged Gold Deflector                                   $5.05
# 48      Rage, Legacy of the Lone Victor                             $4.96
# 158     Darkheart, Butcher of the Champion                          $4.90
# 51      Endbringer                                                  $4.66
# 134     Undead Crusader                                             $4.50
# 30      Stormcaller                                                 $4.42
# 135     Warped Diamond Crusader                                     $4.20
# 91      Celeste                                                     $4.17
# 177     Winterthorn, Defender of Shifting Worlds                    $4.16
# 70      Hope's End                                                  $4.12
# 115     Spectral Diamond Doomblade                                  $4.08
# 69      Frenzy, Defender of the Harvest                             $3.96
# 47      Alpha, Reach of Ending Hope                                 $3.58
# 180     Stormcaller                                                 $3.36
# 27      Riddle, Tribute of Ended Dreams                             $3.30
# 183     Dragon's Greatsword                                         $3.27
# 31      Trickster                                                   $3.10
# 168     Sun Strike, Jaws of Twisted Visions                         $2.96
# 90      Betrayer                                                    $2.94
# 33      Curved Axe                                                  $2.32
# 26      Unholy Wand                                                 $2.24
# 118     Ghost Reaver, Longsword of Magic                            $2.17
# 28      Flux, Destroyer of Due Diligence                            $2.12
# 125     Whistling Mithril Warblade                                  $2.00
# 126     Exiled Mithril Longsword                                    $2.00
# 23      Crucifer                                                    $1.99
# 104     Gladiator's Glaive                                          $1.93
# 42      The Decapitator                                             $1.75
#
# [183 rows x 3 columns]
